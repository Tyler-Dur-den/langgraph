# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict
from langchain_groq import ChatGroq
from langgraph.checkpoint.memory import InMemorySaver
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
llm = ChatGroq(model_name="llama-3.3-70b-versatile", temperature=0.7)

# %%
class JokeState(TypedDict):
    topic: str
    joke: str
    explanation: str

# %%
def generate_joke(state: JokeState):

    prompt = f'generate a joke on the topic {state["topic"]}'
    response = llm.invoke(prompt).content

    return {'joke': response}

# %%
def explain_joke(state: JokeState):
    prompt = f'write an explanation for the joke - {state["joke"]}'
    response = llm.invoke(prompt).content

    return { "explanation": response}

# %%
checkpointer = InMemorySaver()
graph = StateGraph(JokeState)

graph.add_node("generate_joke",generate_joke)
graph.add_node("explain_joke",explain_joke)

graph.add_edge(START, "generate_joke")
graph.add_edge("generate_joke", "explain_joke")
graph.add_edge("explain_joke", END)

workflow = graph.compile(checkpointer=checkpointer)

# %%
config1 = {"configurable": {"thread_id": "1"}}
workflow.invoke({"topic": "football"}, config=config1)
# Out:
# {'topic': 'football',
#  'joke': 'Why did the football go to the doctor?\n\nBecause it was feeling a little "deflated"! (get it?)',
#  'explanation': 'A classic play on words. The joke relies on a clever pun to create humor. Here\'s a breakdown of how it works:\n\nThe setup for the joke is "Why did the football go to the doctor?" which immediately suggests that something is wrong with the football. The listener is expecting a reason related to an injury or illness.\n\nThe punchline "Because it was feeling a little \'deflated\'!" is where the wordplay comes in. In this context, "deflated" has a double meaning:\n\n1. **Literal meaning**: A football can become deflated when it loses air, which affects its shape and functionality. This is a common issue in sports, especially in American football.\n2. **Figurative meaning**: "Deflated" can also describe a person or object that is feeling sad, depressed, or lacking energy. In this sense, the football is personified, and "deflated" is used to convey a emotional state.\n\nThe humor comes from the unexpected twist on the word "deflated". The listener is initially thinking about the physical state of the football, but the joke suddenly shifts to a clever play on words, using the emotional connotation of "deflated" to create a amusing connection between the football\'s physical state and its "feelings". The "(get it?)" at the end is a nod to the listener, acknowledging the clever wordplay and inviting them to appreciate the joke.'}

# %%
workflow.get_state(config1)
# Out:
# StateSnapshot(values={'topic': 'football', 'joke': 'Why did the football go to the doctor?\n\nBecause it was feeling a little "deflated"! (get it?)', 'explanation': 'A classic play on words. The joke relies on a clever pun to create humor. Here\'s a breakdown of how it works:\n\nThe setup for the joke is "Why did the football go to the doctor?" which immediately suggests that something is wrong with the football. The listener is expecting a reason related to an injury or illness.\n\nThe punchline "Because it was feeling a little \'deflated\'!" is where the wordplay comes in. In this context, "deflated" has a double meaning:\n\n1. **Literal meaning**: A football can become deflated when it loses air, which affects its shape and functionality. This is a common issue in sports, especially in American football.\n2. **Figurative meaning**: "Deflated" can also describe a person or object that is feeling sad, depressed, or lacking energy. In this sense, the football is personified, and "deflated" is used to convey a emotional state.\n\nThe humor comes from the unexpected twist on the word "deflated". The listener is initially thinking about the physical state of the football, but the joke suddenly shifts to a clever play on words, using the emotional connotation of "deflated" to create a amusing connection between the football\'s physical state and its "feelings". The "(get it?)" at the end is a nod to the listener, acknowledging the clever wordplay and inviting them to appreciate the joke.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1956d6-8abb-685f-8002-e4eed5ac34dd'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-08-11T10:14:16.525423+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1956d6-7e59-60a3-8001-5f301fc37063'}}, tasks=(), interrupts=())

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'football', 'joke': 'Why did the football go to the doctor?\n\nBecause it was feeling a little "deflated"! (get it?)', 'explanation': 'A classic play on words. The joke relies on a clever pun to create humor. Here\'s a breakdown of how it works:\n\nThe setup for the joke is "Why did the football go to the doctor?" which immediately suggests that something is wrong with the football. The listener is expecting a reason related to an injury or illness.\n\nThe punchline "Because it was feeling a little \'deflated\'!" is where the wordplay comes in. In this context, "deflated" has a double meaning:\n\n1. **Literal meaning**: A football can become deflated when it loses air, which affects its shape and functionality. This is a common issue in sports, especially in American football.\n2. **Figurative meaning**: "Deflated" can also describe a person or object that is feeling sad, depressed, or lacking energy. In this sense, the football is personified, and "deflated" is used to convey a emotional state.\n\nThe humor comes from the unexpected twist on the word "deflated". The listener is initially thinking about the physical state of the football, but the joke suddenly shifts to a clever play on words, using the emotional connotation of "deflated" to create a amusing connection between the football\'s physical state and its "feelings". The "(get it?)" at the end is a nod to the listener, acknowledging the clever wordplay and inviting them to appreciate the joke.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1956d6-8abb-685f-8002-e4eed5ac34dd'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-08-11T10:14:16.525423+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1956d6-7e59-60a3-8001-5f301fc37063'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'football', 'joke': 'Why did the football go to the doctor?\n\nBecause it was feeling a little "deflated"! (get it?)'}, next=('explain_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1956d6-7e59-60a3-8001-5f301fc37063'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-08-11T10:14:15.226793+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1956d6-79b0-6b22-8000-d6d34530441f'}}, tasks=(PregelTask(id='0cc13466-c0ff-112f-20cb-041725dabd86', name='explain_joke', path=('__pregel_pull', 'explain_joke'), error=None, interrupts=(), state=None, result={'explanation': 'A classic play on words. The joke relies on a clever pun to create humor. Here\'s a breakdown of how it works:\n\nThe setup for the joke is "Why did the football go to the doctor?" which immediately suggests that something is wrong with the football. The listener is expecting a reason related to an injury or illness.\n\nThe punchline "Because it was feeling a little \'deflated\'!" is where the wordplay comes in. In this context, "deflated" has a double meaning:\n\n1. **Literal meaning**: A football can become deflated when it loses air, which affects its shape and functionality. This is a common issue in sports, especially in American football.\n2. **Figurative meaning**: "Deflated" can also describe a person or object that is feeling sad, depressed, or lacking energy. In this sense, the football is personified, and "deflated" is used to convey a emotional state.\n\nThe humor comes from the unexpected twist on the word "deflated". The listener is initially thinking about the physical state of the football, but the joke suddenly shifts to a clever play on words, using the emotional connotation of "deflated" to create a amusing connection between the football\'s physical state and its "feelings". The "(get it?)" at the end is a nod to the listener, acknowledging the clever wordplay and inviting them to appreciate the joke.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'football'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1956d6-79b0-6b22-8000-d6d34530441f'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-08-11T10:14:14.738409+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1956d6-79a9-65a4-bfff-3e47e1369f6d'}}, tasks=(PregelTask(id='bb1dc300-1655-31b6-debb-ba75702259a6', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the football go to the doctor?\n\nBecause it was feeling a little "deflated"! (get it?)'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f1956d6-79a9-65a4-bfff-3e47e1369f6d'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-08-11T10:14:14.735402+00:00', parent_config=None, tasks=(PregelTask(id='27b3659e-6c89-debe-06e1-7f2d5ad88fbc', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'football'}),), interrupts=())]

# %%
config2 = {"configurable": {"thread_id": "2"}}
workflow.invoke({'topic':'Cricket'}, config=config2)
# Out:
# {'topic': 'Cricket',
#  'joke': 'Why did the cricket go to the doctor?\n\nBecause it had a "sticky" wicket problem and was feeling a little "bowled" over!',
#  'explanation': 'A joke that\'s a pitch-perfect blend of cricket terminology and wordplay.\n\nThe joke relies on a double meaning of two cricket-related terms: "sticky wicket" and "bowled over." In cricket, a "sticky wicket" refers to a difficult or challenging situation on the field, often due to a damp or uneven pitch. However, the word "sticky" can also imply something being stuck or adhering to something else.\n\nIn this joke, the cricket (the insect) goes to the doctor with a "sticky wicket problem," which is a play on words. The phrase is used to describe a situation where the cricket might be literally stuck, perhaps to a surface or in a predicament, rather than a metaphorical challenge on a cricket field.\n\nThe second part of the joke, "feeling a little \'bowled over,\'" is another clever use of cricket terminology. In cricket, a player can be "bowled over" when they are hit by a ball and their wickets (three vertical stumps and two horizontal sticks) are knocked over. However, the phrase "bowled over" is also an idiomatic expression meaning to be overwhelmed, surprised, or shocked.\n\nSo, in this joke, the cricket is not only experiencing a "sticky" situation but also feeling overwhelmed or "bowled over" by its problem, hence the visit to the doctor. The joke requires a basic understanding of cricket terminology and the ability to appreciate the wordplay involved, making it a clever and amusing pun for those familiar with the sport.'}

# %%
workflow.get_state(config2)
# Out:
# StateSnapshot(values={'topic': 'Cricket', 'joke': 'Why did the cricket go to the doctor?\n\nBecause it had a "sticky" wicket problem and was feeling a little "bowled" over!', 'explanation': 'A joke that\'s a pitch-perfect blend of cricket terminology and wordplay.\n\nThe joke relies on a double meaning of two cricket-related terms: "sticky wicket" and "bowled over." In cricket, a "sticky wicket" refers to a difficult or challenging situation on the field, often due to a damp or uneven pitch. However, the word "sticky" can also imply something being stuck or adhering to something else.\n\nIn this joke, the cricket (the insect) goes to the doctor with a "sticky wicket problem," which is a play on words. The phrase is used to describe a situation where the cricket might be literally stuck, perhaps to a surface or in a predicament, rather than a metaphorical challenge on a cricket field.\n\nThe second part of the joke, "feeling a little \'bowled over,\'" is another clever use of cricket terminology. In cricket, a player can be "bowled over" when they are hit by a ball and their wickets (three vertical stumps and two horizontal sticks) are knocked over. However, the phrase "bowled over" is also an idiomatic expression meaning to be overwhelmed, surprised, or shocked.\n\nSo, in this joke, the cricket is not only experiencing a "sticky" situation but also feeling overwhelmed or "bowled over" by its problem, hence the visit to the doctor. The joke requires a basic understanding of cricket terminology and the ability to appreciate the wordplay involved, making it a clever and amusing pun for those familiar with the sport.'}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1956d8-9b90-6efc-8002-10ef9b4eda75'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-08-11T10:15:11.977650+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1956d8-8e99-62a4-8001-442afd63b0f0'}}, tasks=(), interrupts=())

# %%
list(workflow.get_state_history(config2))
# Out:
# [StateSnapshot(values={'topic': 'Cricket', 'joke': 'Why did the cricket go to the doctor?\n\nBecause it had a "sticky" wicket problem and was feeling a little "bowled" over!', 'explanation': 'A joke that\'s a pitch-perfect blend of cricket terminology and wordplay.\n\nThe joke relies on a double meaning of two cricket-related terms: "sticky wicket" and "bowled over." In cricket, a "sticky wicket" refers to a difficult or challenging situation on the field, often due to a damp or uneven pitch. However, the word "sticky" can also imply something being stuck or adhering to something else.\n\nIn this joke, the cricket (the insect) goes to the doctor with a "sticky wicket problem," which is a play on words. The phrase is used to describe a situation where the cricket might be literally stuck, perhaps to a surface or in a predicament, rather than a metaphorical challenge on a cricket field.\n\nThe second part of the joke, "feeling a little \'bowled over,\'" is another clever use of cricket terminology. In cricket, a player can be "bowled over" when they are hit by a ball and their wickets (three vertical stumps and two horizontal sticks) are knocked over. However, the phrase "bowled over" is also an idiomatic expression meaning to be overwhelmed, surprised, or shocked.\n\nSo, in this joke, the cricket is not only experiencing a "sticky" situation but also feeling overwhelmed or "bowled over" by its problem, hence the visit to the doctor. The joke requires a basic understanding of cricket terminology and the ability to appreciate the wordplay involved, making it a clever and amusing pun for those familiar with the sport.'}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1956d8-9b90-6efc-8002-10ef9b4eda75'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-08-11T10:15:11.977650+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1956d8-8e99-62a4-8001-442afd63b0f0'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'Cricket', 'joke': 'Why did the cricket go to the doctor?\n\nBecause it had a "sticky" wicket problem and was feeling a little "bowled" over!'}, next=('explain_joke',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1956d8-8e99-62a4-8001-442afd63b0f0'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-08-11T10:15:10.617872+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1956d8-8b7b-6d76-8000-5621630a7285'}}, tasks=(PregelTask(id='cfb932fd-274b-56d7-1399-46e9bfa70547', name='explain_joke', path=('__pregel_pull', 'explain_joke'), error=None, interrupts=(), state=None, result={'explanation': 'A joke that\'s a pitch-perfect blend of cricket terminology and wordplay.\n\nThe joke relies on a double meaning of two cricket-related terms: "sticky wicket" and "bowled over." In cricket, a "sticky wicket" refers to a difficult or challenging situation on the field, often due to a damp or uneven pitch. However, the word "sticky" can also imply something being stuck or adhering to something else.\n\nIn this joke, the cricket (the insect) goes to the doctor with a "sticky wicket problem," which is a play on words. The phrase is used to describe a situation where the cricket might be literally stuck, perhaps to a surface or in a predicament, rather than a metaphorical challenge on a cricket field.\n\nThe second part of the joke, "feeling a little \'bowled over,\'" is another clever use of cricket terminology. In cricket, a player can be "bowled over" when they are hit by a ball and their wickets (three vertical stumps and two horizontal sticks) are knocked over. However, the phrase "bowled over" is also an idiomatic expression meaning to be overwhelmed, surprised, or shocked.\n\nSo, in this joke, the cricket is not only experiencing a "sticky" situation but also feeling overwhelmed or "bowled over" by its problem, hence the visit to the doctor. The joke requires a basic understanding of cricket terminology and the ability to appreciate the wordplay involved, making it a clever and amusing pun for those familiar with the sport.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'Cricket'}, next=('generate_joke',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1956d8-8b7b-6d76-8000-5621630a7285'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-08-11T10:15:10.291288+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1956d8-8b79-6639-bfff-c9b077c35290'}}, tasks=(PregelTask(id='f42c349c-77f4-568a-4e10-80e6bf7b8ebf', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the cricket go to the doctor?\n\nBecause it had a "sticky" wicket problem and was feeling a little "bowled" over!'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f1956d8-8b79-6639-bfff-c9b077c35290'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-08-11T10:15:10.290284+00:00', parent_config=None, tasks=(PregelTask(id='6e29d6cc-f31a-57d1-984f-066893fcbcf4', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'Cricket'}),), interrupts=())]
