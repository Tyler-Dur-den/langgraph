# %%
from langgraph.graph import StateGraph, START, END
from typing import TypedDict
from langchain_groq import ChatGroq
from langgraph.checkpoint.memory import InMemorySaver
from dotenv import load_dotenv
load_dotenv()
# Out:
# True

# %%
llm = ChatGroq(model_name="llama-3.3-70b-versatile", temperature=0.7)

# %%
class JokeState(TypedDict):
    topic: str
    joke: str
    explanation: str

# %%
def generate_joke(state: JokeState):

    prompt = f'generate a joke on the topic {state["topic"]}'
    response = llm.invoke(prompt).content

    return {'joke': response}

# %%
def explain_joke(state: JokeState):
    prompt = f'write an explanation for the joke - {state["joke"]}'
    response = llm.invoke(prompt).content

    return { "explanation": response}

# %%
checkpointer = InMemorySaver()
graph = StateGraph(JokeState)

graph.add_node("generate_joke",generate_joke)
graph.add_node("explain_joke",explain_joke)

graph.add_edge(START, "generate_joke")
graph.add_edge("generate_joke", "explain_joke")
graph.add_edge("explain_joke", END)

workflow = graph.compile(checkpointer=checkpointer)

# %%
config1 = {"configurable": {"thread_id": "1"}}
workflow.invoke({"topic": "football"}, config=config1)
# Out:
# {'topic': 'football',
#  'joke': 'Why did the football go to the doctor?\n\nBecause it was feeling a little "deflated"! (get it?)',
#  'explanation': 'A clever play on words. This joke is funny because it uses a pun to create a humorous connection between the setup and the punchline. Here\'s how it works:\n\nThe joke starts by asking why a football went to the doctor, which sets up the expectation that the football is experiencing some kind of problem or injury. The punchline, "it was feeling a little \'deflated\'," is a clever wordplay because "deflated" has a double meaning in this context.\n\nIn one sense, "deflated" can refer to a football that has lost air, which is a common issue with inflatable balls like footballs. However, "deflated" can also be used to describe someone or something that is feeling unenthusiastic, depressed, or lacking energy.\n\nThe joke relies on this double meaning to create a humorous connection between the setup and the punchline. The speaker is making a clever connection between the physical state of a football (losing air) and the emotional state of feeling unwell or unhappy. The phrase "get it?" at the end of the joke is a nod to the wordplay, inviting the listener to appreciate the cleverness of the pun.\n\nOverall, the joke is funny because it uses a clever play on words to create a unexpected and clever connection between the setup and the punchline, making it a lighthearted and amusing joke.'}

# %%
workflow.get_state(config1)
# Out:
# StateSnapshot(values={'topic': 'football', 'joke': 'Why did the football go to the doctor?\n\nBecause it was feeling a little "deflated"! (get it?)', 'explanation': 'A clever play on words. This joke is funny because it uses a pun to create a humorous connection between the setup and the punchline. Here\'s how it works:\n\nThe joke starts by asking why a football went to the doctor, which sets up the expectation that the football is experiencing some kind of problem or injury. The punchline, "it was feeling a little \'deflated\'," is a clever wordplay because "deflated" has a double meaning in this context.\n\nIn one sense, "deflated" can refer to a football that has lost air, which is a common issue with inflatable balls like footballs. However, "deflated" can also be used to describe someone or something that is feeling unenthusiastic, depressed, or lacking energy.\n\nThe joke relies on this double meaning to create a humorous connection between the setup and the punchline. The speaker is making a clever connection between the physical state of a football (losing air) and the emotional state of feeling unwell or unhappy. The phrase "get it?" at the end of the joke is a nod to the wordplay, inviting the listener to appreciate the cleverness of the pun.\n\nOverall, the joke is funny because it uses a clever play on words to create a unexpected and clever connection between the setup and the punchline, making it a lighthearted and amusing joke.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f195b4d-97d4-647b-8002-2a8ff422f9ea'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-08-11T18:45:40.071333+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f195b4d-8c19-6f25-8001-361639f3fe15'}}, tasks=(), interrupts=())

# %%
list(workflow.get_state_history(config1))
# Out:
# [StateSnapshot(values={'topic': 'football', 'joke': 'Why did the football go to the doctor?\n\nBecause it was feeling a little "deflated"! (get it?)', 'explanation': 'A clever play on words. This joke is funny because it uses a pun to create a humorous connection between the setup and the punchline. Here\'s how it works:\n\nThe joke starts by asking why a football went to the doctor, which sets up the expectation that the football is experiencing some kind of problem or injury. The punchline, "it was feeling a little \'deflated\'," is a clever wordplay because "deflated" has a double meaning in this context.\n\nIn one sense, "deflated" can refer to a football that has lost air, which is a common issue with inflatable balls like footballs. However, "deflated" can also be used to describe someone or something that is feeling unenthusiastic, depressed, or lacking energy.\n\nThe joke relies on this double meaning to create a humorous connection between the setup and the punchline. The speaker is making a clever connection between the physical state of a football (losing air) and the emotional state of feeling unwell or unhappy. The phrase "get it?" at the end of the joke is a nod to the wordplay, inviting the listener to appreciate the cleverness of the pun.\n\nOverall, the joke is funny because it uses a clever play on words to create a unexpected and clever connection between the setup and the punchline, making it a lighthearted and amusing joke.'}, next=(), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f195b4d-97d4-647b-8002-2a8ff422f9ea'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-08-11T18:45:40.071333+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f195b4d-8c19-6f25-8001-361639f3fe15'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'football', 'joke': 'Why did the football go to the doctor?\n\nBecause it was feeling a little "deflated"! (get it?)'}, next=('explain_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f195b4d-8c19-6f25-8001-361639f3fe15'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-08-11T18:45:38.841578+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f195b4d-87ea-6988-8000-bbe631ab8238'}}, tasks=(PregelTask(id='0e55c9be-34ef-73e7-4bde-c35f7dd45176', name='explain_joke', path=('__pregel_pull', 'explain_joke'), error=None, interrupts=(), state=None, result={'explanation': 'A clever play on words. This joke is funny because it uses a pun to create a humorous connection between the setup and the punchline. Here\'s how it works:\n\nThe joke starts by asking why a football went to the doctor, which sets up the expectation that the football is experiencing some kind of problem or injury. The punchline, "it was feeling a little \'deflated\'," is a clever wordplay because "deflated" has a double meaning in this context.\n\nIn one sense, "deflated" can refer to a football that has lost air, which is a common issue with inflatable balls like footballs. However, "deflated" can also be used to describe someone or something that is feeling unenthusiastic, depressed, or lacking energy.\n\nThe joke relies on this double meaning to create a humorous connection between the setup and the punchline. The speaker is making a clever connection between the physical state of a football (losing air) and the emotional state of feeling unwell or unhappy. The phrase "get it?" at the end of the joke is a nod to the wordplay, inviting the listener to appreciate the cleverness of the pun.\n\nOverall, the joke is funny because it uses a clever play on words to create a unexpected and clever connection between the setup and the punchline, making it a lighthearted and amusing joke.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'football'}, next=('generate_joke',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f195b4d-87ea-6988-8000-bbe631ab8238'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-08-11T18:45:38.402752+00:00', parent_config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f195b4d-87ea-6987-bfff-b8a20e468bae'}}, tasks=(PregelTask(id='ae8639ec-5337-e63b-014a-17998f011706', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the football go to the doctor?\n\nBecause it was feeling a little "deflated"! (get it?)'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '1', 'checkpoint_ns': '', 'checkpoint_id': '1f195b4d-87ea-6987-bfff-b8a20e468bae'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-08-11T18:45:38.402752+00:00', parent_config=None, tasks=(PregelTask(id='de6ebc63-bc23-fcea-bc2c-5479e44cba8d', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'football'}),), interrupts=())]

# %%
config2 = {"configurable": {"thread_id": "2"}}
workflow.invoke({'topic':'Cricket'}, config=config2)
# Out:
# {'topic': 'Cricket',
#  'joke': 'Why did the cricket ball go to therapy?\n\nBecause it was feeling a little "bowled" over by its emotions!',
#  'explanation': 'A classic play on words. This joke is a pun that relies on a double meaning of the phrase "bowled over." In cricket, a ball can be "bowled" by the opposing team\'s bowler, which means it is thrown in such a way that it knocks over the batsman\'s wicket. However, in everyday language, "bowled over" is an idiomatic expression that means being completely overwhelmed or surprised by something, often emotions.\n\nThe joke sets up the expectation that a cricket ball would not typically have emotions or go to therapy. But the punchline subverts this expectation by using the phrase "bowled over" in a way that references both the cricket term and the emotional state. The humor comes from the clever connection between the literal meaning of "bowled" in cricket and the figurative meaning of being overwhelmed by emotions. It\'s a lighthearted and clever play on words that creates a humorous effect.'}

# %%
workflow.get_state(config2)
# Out:
# StateSnapshot(values={'topic': 'Cricket', 'joke': 'Why did the cricket ball go to therapy?\n\nBecause it was feeling a little "bowled" over by its emotions!', 'explanation': 'A classic play on words. This joke is a pun that relies on a double meaning of the phrase "bowled over." In cricket, a ball can be "bowled" by the opposing team\'s bowler, which means it is thrown in such a way that it knocks over the batsman\'s wicket. However, in everyday language, "bowled over" is an idiomatic expression that means being completely overwhelmed or surprised by something, often emotions.\n\nThe joke sets up the expectation that a cricket ball would not typically have emotions or go to therapy. But the punchline subverts this expectation by using the phrase "bowled over" in a way that references both the cricket term and the emotional state. The humor comes from the clever connection between the literal meaning of "bowled" in cricket and the figurative meaning of being overwhelmed by emotions. It\'s a lighthearted and clever play on words that creates a humorous effect.'}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f195b4d-a388-6df1-8002-03faf98d0558'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-08-11T18:45:41.298737+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f195b4d-9b04-6ac9-8001-f078812aeef1'}}, tasks=(), interrupts=())

# %%
list(workflow.get_state_history(config2))
# Out:
# [StateSnapshot(values={'topic': 'Cricket', 'joke': 'Why did the cricket ball go to therapy?\n\nBecause it was feeling a little "bowled" over by its emotions!', 'explanation': 'A classic play on words. This joke is a pun that relies on a double meaning of the phrase "bowled over." In cricket, a ball can be "bowled" by the opposing team\'s bowler, which means it is thrown in such a way that it knocks over the batsman\'s wicket. However, in everyday language, "bowled over" is an idiomatic expression that means being completely overwhelmed or surprised by something, often emotions.\n\nThe joke sets up the expectation that a cricket ball would not typically have emotions or go to therapy. But the punchline subverts this expectation by using the phrase "bowled over" in a way that references both the cricket term and the emotional state. The humor comes from the clever connection between the literal meaning of "bowled" in cricket and the figurative meaning of being overwhelmed by emotions. It\'s a lighthearted and clever play on words that creates a humorous effect.'}, next=(), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f195b4d-a388-6df1-8002-03faf98d0558'}}, metadata={'source': 'loop', 'step': 2, 'parents': {}}, created_at='2026-08-11T18:45:41.298737+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f195b4d-9b04-6ac9-8001-f078812aeef1'}}, tasks=(), interrupts=()),
#  StateSnapshot(values={'topic': 'Cricket', 'joke': 'Why did the cricket ball go to therapy?\n\nBecause it was feeling a little "bowled" over by its emotions!'}, next=('explain_joke',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f195b4d-9b04-6ac9-8001-f078812aeef1'}}, metadata={'source': 'loop', 'step': 1, 'parents': {}}, created_at='2026-08-11T18:45:40.405728+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f195b4d-9819-6033-8000-96a0ef48778b'}}, tasks=(PregelTask(id='379d8c51-8936-e22a-2e16-69052e661c8e', name='explain_joke', path=('__pregel_pull', 'explain_joke'), error=None, interrupts=(), state=None, result={'explanation': 'A classic play on words. This joke is a pun that relies on a double meaning of the phrase "bowled over." In cricket, a ball can be "bowled" by the opposing team\'s bowler, which means it is thrown in such a way that it knocks over the batsman\'s wicket. However, in everyday language, "bowled over" is an idiomatic expression that means being completely overwhelmed or surprised by something, often emotions.\n\nThe joke sets up the expectation that a cricket ball would not typically have emotions or go to therapy. But the punchline subverts this expectation by using the phrase "bowled over" in a way that references both the cricket term and the emotional state. The humor comes from the clever connection between the literal meaning of "bowled" in cricket and the figurative meaning of being overwhelmed by emotions. It\'s a lighthearted and clever play on words that creates a humorous effect.'}),), interrupts=()),
#  StateSnapshot(values={'topic': 'Cricket'}, next=('generate_joke',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f195b4d-9819-6033-8000-96a0ef48778b'}}, metadata={'source': 'loop', 'step': 0, 'parents': {}}, created_at='2026-08-11T18:45:40.099486+00:00', parent_config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f195b4d-9816-6929-bfff-8bd30f6b57ae'}}, tasks=(PregelTask(id='1bb243a7-1af3-6bdb-0487-5f46998d808e', name='generate_joke', path=('__pregel_pull', 'generate_joke'), error=None, interrupts=(), state=None, result={'joke': 'Why did the cricket ball go to therapy?\n\nBecause it was feeling a little "bowled" over by its emotions!'}),), interrupts=()),
#  StateSnapshot(values={}, next=('__start__',), config={'configurable': {'thread_id': '2', 'checkpoint_ns': '', 'checkpoint_id': '1f195b4d-9816-6929-bfff-8bd30f6b57ae'}}, metadata={'source': 'input', 'step': -1, 'parents': {}}, created_at='2026-08-11T18:45:40.098487+00:00', parent_config=None, tasks=(PregelTask(id='12239d05-9461-61f6-bcfb-e206f23bd5b0', name='__start__', path=('__pregel_pull', '__start__'), error=None, interrupts=(), state=None, result={'topic': 'Cricket'}),), interrupts=())]
